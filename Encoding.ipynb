# %%
import pandas as pd

# %%
df = pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
X = df.iloc[:,1:]

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
y = df.iloc[:,[1]]

# %%
y.head()
# Out:
#    area
# 0  7420
# 1  8960
# 2  9960
# 3  7500
# 4  7420

# %%
num_cols = list(X.dtypes[X.dtypes != 'O'].index)
num_cols
# Out:
# ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
cat_cols = list(X.dtypes[X.dtypes == 'O'].index)
cat_cols
# Out:
# ['mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'prefarea',
#  'furnishingstatus']

# %%
X['mainroad'].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
ode = OrdinalEncoder()

# %%
X['mainroad'] = ode.fit_transform(X[['mainroad']])

# %%
X['mainroad'].value_counts()
# Out:
# 1.0    468
# 0.0     77
# Name: mainroad, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
X['basement'].value_counts()
# Out:
# no     354
# yes    191
# Name: basement, dtype: int64

# %%
feature = ohe.fit_transform(X[['basement',]]).toarray()

#feature = ohe.fit_transform(X[['basement','mainroad','guestroom']]).toarray()

# %%
import numpy as np
labels = ohe.categories_
print(labels)
labels = np.array(labels).ravel()
# Out:
# [array(['no', 'yes'], dtype=object)]

# %%
temp = pd.DataFrame(feature,columns = labels)

# %%
temp.head()
# Out:
#     no  yes
# 0  1.0  0.0
# 1  1.0  0.0
# 2  0.0  1.0
# 3  0.0  1.0
# 4  0.0  1.0

# %%
X = pd.concat([X,temp],axis = 1)

# %%
#X.drop(['basement','no'],axis=1,inplace=True)

# %%
#X['yes'].value_counts()

# %%
X['guestroom'].value_counts()
# Out:
# no     448
# yes     97
# Name: guestroom, dtype: int64

# %%
temp = pd.get_dummies(X['guestroom'])
temp

# %%
X = pd.concat([X,temp],axis = 1)

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  7420         4          2        3       1.0        no       no
# 1  8960         4          4        4       1.0        no       no
# 2  9960         3          2        2       1.0        no      yes
# 3  7500         4          2        2       1.0        no      yes
# 4  7420         4          1        2       1.0       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus   no  \
# 0              no             yes        2      yes        furnished  1.0
# 1              no             yes        3       no        furnished  1.0
# 2              no              no        2      yes   semi-furnished  0.0
# 3              no             yes        3      yes        furnished  0.0
# 4              no             yes        2       no        furnished  0.0
#
#    yes  no  yes
# 0  0.0   1    0
# 1  0.0   1    0
# 2  1.0   1    0
# 3  1.0   1    0
# 4  1.0   0    1

# %%
df['hotwaterheating'].value_counts()
# Out:
# no     520
# yes     25
# Name: hotwaterheating, dtype: int64

# %%
hotwater = {'no':0 ,'yes':1}

# %%
df['hotwaterheating'] = df['hotwaterheating'].map(hotwater)

# %%
df['hotwaterheating'].value_counts()
# Out:
# 0    520
# 1     25
# Name: hotwaterheating, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (436, 12)
# (436, 1)
# (109, 12)
# (109, 1)

# %%
num_cols = list(X_train.dtypes[X_train.dtypes != 'O'].index)
num_cols
# Out:
# ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
cat_cols = list(X_train.dtypes[X_train.dtypes == 'O'].index)
cat_cols
# Out:
# ['mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'prefarea',
#  'furnishingstatus']

# %%
df['main']
